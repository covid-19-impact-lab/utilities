# %%
import data_cleaning as dc
import pandas as pd

# %%
data_path = '../../../liss-data/data/xyx-corona-questionnaire/' + \
    'L_Coronavirus_impact_23032020_4p.sav'

data = pd.read_spss(data_path)

description = dc._load_description(
    "covid19_data_description.csv", "xyx-corona-questionnaire.dta")

# %%
dc.check_description(
    data=data, data_name="xyx-corona-questionnaire.dta", 
    description=description, logging="print")
# Out:
# The following variables from the raw dataset are not covered by the description table:
# 	DatumB
# 	DatumE
# 	TijdB
# 	TijdE
# 	aantalhh
# 	aantalki
# 	belbezig
# 	brutocat
# 	brutohh_f
# 	brutoink
# 	brutoink_f
# 	burgstat
# 	duur
# 	eva2t1
# 	eva2t2
# 	eva2t3
# 	eva2t4
# 	eva2t5
# 	evaopm
# 	geslacht
# 	leeftijd
# 	lftdcat
# 	lftdhhh
# 	maandnr
# 	netinc
# 	nettocat
# 	nettohh_f
# 	nettoink
# 	nettoink_f
# 	nohouse_encr
# 	oplcat
# 	oplmet
# 	oplzon
# 	opm
# 	partner
# 	positie
# 	q11__7
# 	q12__8
# 	q14a
# 	q14b
# 	q14c
# 	q14d
# 	q15__6
# 	q16__5
# 	q17__4
# 	q23__10
# 	q25a
# 	q25b
# 	q26a
# 	q26b
# 	q26c
# 	q26d
# 	q29__999
# 	q29and
# 	q32
# 	q34a
# 	q34b
# 	sted
# 	woning
# 	woonvorm
#
#
#
#
# The following variables from the description table are not in the raw dataset:
# 	False
# 	True
# 	eva2h
# 	nan
# 	note
# 	q25open
# 	q29__7
# 	v1
# 	v2a
# 	v2b
# 	v2c
# 	v2d
# 	v2e
# 	v2f
# 	v3
# 	v4
# 	v5a
# 	v5c
# 	v5d
# 	v5e
# 	v5f
# 	v61
# 	v62
# 	v63
# 	v64

# %% [markdown]
# # Look at snapshot

# %%
data = pd.read_pickle('../../../liss-data/bld/out/data/corona.pickle')

data.head()
# Out:
#                          p_infected p_acquaintance_infected  \
# personal_id year
# 800100      2018        very likely             very likely
# 800131      2018    rather unlikely           rather likely
# 800161      2018    rather unlikely         rather unlikely
# 800170      2018      rather likely           rather likely
# 800186      2018  moderately likely       moderately likely
#
#                  p_hospital_if_infect_self      p_quarantaine  \
# personal_id year
# 800100      2018               very likely  moderately likely
# 800131      2018               very likely        very likely
# 800161      2018           rather unlikely    rather unlikely
# 800170      2018           rather unlikely      rather likely
# 800186      2018         moderately likely    rather unlikely
#
#                  p_infected_and_pass_on p_hospital_healthy_30  \
# personal_id year
# 800100      2018      moderately likely                   NaN
# 800131      2018        rather unlikely       rather unlikely
# 800161      2018          rather likely       rather unlikely
# 800170      2018      moderately likely         very unlikely
# 800186      2018        rather unlikely       rather unlikely
#
#                  p_die_healthy_30 p_hospital_healthy_75 p_die_healthy_75  \
# personal_id year
# 800100      2018              NaN                   NaN      very likely
# 800131      2018  rather unlikely                   NaN              NaN
# 800161      2018    very unlikely       rather unlikely    very unlikely
# 800170      2018    very unlikely         rather likely              NaN
# 800186      2018  rather unlikely                   NaN    rather likely
#
#                  p_hospital_healthy_5  ... concern_new_job concern_food  \
# personal_id year                       ...
# 800100      2018          very likely  ...            <NA>            1
# 800131      2018        very unlikely  ...            <NA>            1
# 800161      2018        very unlikely  ...            <NA>            1
# 800170      2018        rather likely  ...            <NA>            1
# 800186      2018      rather unlikely  ...            <NA>            2
#
#                  concern_health_care concern_fav_shop_bancrupt date_period  \
# personal_id year
# 800100      2018                   1                         1      201803
# 800131      2018                   1                         1      201803
# 800161      2018                   2                         3      201803
# 800170      2018                   1                         1      201803
# 800186      2018                   4                         1      201803
#
#                  infected acquaintance_infected hospital_if_infect_self  \
# personal_id year
# 800100      2018    False                 False                   False
# 800131      2018    False                 False                   False
# 800161      2018    False                 False                   False
# 800170      2018    False                 False                   False
# 800186      2018    False                 False                   False
#
#                  quarantaine infected_and_pass_on
# personal_id year
# 800100      2018       False                False
# 800131      2018       False                False
# 800161      2018       False                False
# 800170      2018       False                False
# 800186      2018       False                False
#
# [5 rows x 138 columns]

# %% [markdown]
# # Load Meta Data from .sav

# %%
import pyreadstat

# %%
df, meta = pyreadstat.read_sav(
    "../../../liss-data/data/xyx-corona-questionnaire/" + 
    "L_coronavirus_maart20_13maart__HM.sav")

# %%
generated_description = pd.Series(
    meta.column_names_to_labels)

generated_description.index.name = "xyx-corona-questionnaire"
generated_description.name = "orig_labels_dutch"
generated_description = generated_description.to_frame()
generated_description["orig_labels_dutch"] = \
    generated_description["orig_labels_dutch"].astype(str)

# %%
from googletrans import Translator
t = Translator()

# generated_description["orig_labels_translated"] = \
#     generated_description["orig_labels_dutch"].apply(
#         lambda x: t.translate(x).text)

# %%
description[description["topic_english"] == "Background Variables"]
# Out:
#     gesis xyx-corona-questionnaire.dta            new_name  \
# 72   True                        False  labor_status_gesis
# 73  False                          q13   labor_status_liss
# 94   True                          NaN        has_children
# 95  False                          q22         nr_children
#
#            topic_english                 group  \
# 72  Background Variables  Background Variables
# 73  Background Variables  Background Variables
# 94  Background Variables  Background Variables
# 95  Background Variables  Background Variables
#
#                                         label_english         type  \
# 72  Which of the following options describes your ...  Categorical
# 73  Which of the following options describes your ...  Categorical
# 94  Are there children below 12 years of age in yo...      boolean
# 95  How many children under 12 are in your household?        Int64
#
#                                    categories_english ordered
# 72  employed, self-emplyed, marginally employed, u...   False
# 73  employed, self-emplyed, unemployed, retired, s...   False
# 94                                                NaN     NaN
# 95                                                NaN     NaN

# %%
# delimit with semi colon
csv = pd.read_csv('covid19_data_description.csv', sep=";")
# csv.to_csv('covid19_data_description.csv', sep=';')

# %%
pd.options.display.max_rows = 300

# %%
to_handle = description[
        (description["type"] == "Categorical") & 
        (description["xyx-corona-questionnaire.dta"].notnull()) & 
        (description["xyx-corona-questionnaire.dta"] != False)
    ][["new_name", "type", "ordered", "categories_english"]]

# %%
to_handle.loc[149:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-baff7f73929c> in <module>
# ----> 1 to_handle.loc[149:]
#
# NameError: name 'to_handle' is not defined

# %%
vc = description["group"].value_counts()
len(vc[vc > 1])
# Out:
# 31

# %%
vc
# Out:
# Work Adjustments                                 17
# Reasons for Disobeying a Curfew                  14
# Reasons for Compliance with Curfew               12
# Childcare Adjustments                            10
# ????                                             10
# Media Diet                                       10
# Social Distancing                                 8
# Economic Adjustments                              7
# Economic Coping Strategies                        7
# Subjective Effectiveness of Policies              7
# Appropriateness of Policies                       6
# Probabilities of Economic Repercussions           6
# Support for Policies                              6
# Subjective Risk of Getting or Spreading           5
# Subjective Risk of Death                          5
# Trust in Health System                            5
# Future Employment State                           5
# Use of One-Time Allowance                         5
# Economic Adjustments II                           5
# Subjective Effectiveness of Social Distancing     5
# Subjective Effectiveness of Health Behaviors      5
# Reasons for Stop Working                          5
# Trust in Government                               5
# Subjective Risk of Hospitalization                5
# Mood in the Last Week                             5
# Economic Concerns                                 5
# Facebook Usage                                    4
# Reasons for Working Less                          4
# Working Hours                                     4
# Health Concerns                                   4
# Background Variables                              3
# Contact with the Elderly                          1
# Compliance with Curfew                            1
# Probability of Severe Financial Distress          1
# Contact with Workers or Students                  1
# Expected Duration of Restrictions                 1
# Duration of the Economic Crisis                   1
# Name: group, dtype: int64
